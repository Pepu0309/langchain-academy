# %% [markdown]
# # Assistants
#
# [Assistants](https://docs.langchain.com/langsmith/assistants) give developers a quick and easy way to modify and version agents for experimentation.
#
# ## Supplying configuration to the graph
#
# Our `task_maistro` graph is already set up to use assistants!
#
# It has a `configuration.py` file defined and loaded in the graph.
#
# We access configurable fields (`user_id`, `todo_category`, `task_maistro_role`) inside the graph nodes.
#
# ## Creating assistants
#
# Now, what is a practical use case for assistants with the `task_maistro` app that we've been building?
#
# For me, it's the ability to have separate ToDo lists for different categories of tasks.
#
# For example, I want one assistant for my personal tasks and another for my work tasks.
#
# These are easily configurable using the `todo_category` and `task_maistro_role` configurable fields.
#
# ![Screenshot 2024-11-18 at 9.35.55 AM.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/673d50597f4e9eae9abf4869_Screenshot%202024-11-19%20at%206.57.01%E2%80%AFPM.png)

# %%
# %%capture --no-stderr
# %pip install -U langgraph_sdk
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# This is the default assistant that we created when we deployed the graph.

# %%
from langgraph_sdk import get_client
url_for_cli_deployment = "http://localhost:8123"
client = get_client(url=url_for_cli_deployment)

# %% [markdown]
# ### Personal assistant
#
# This is the personal assistant that I'll use to manage my personal tasks.

# %%
personal_assistant = await client.assistants.create(
    # "task_maistro" is the name of a graph we deployed
    "task_maistro", 
    config={"configurable": {"todo_category": "personal"}}
)
print(personal_assistant)
# Out:
# {'assistant_id': 'ba9ce6ca-6999-4b44-a552-56d5c587407e', 'graph_id': 'task_maistro', 'version': 1, 'created_at': '2026-05-11T06:24:28.570499+00:00', 'updated_at': '2026-05-11T06:24:28.570499+00:00', 'config': {'configurable': {'todo_category': 'personal'}}, 'context': {'todo_category': 'personal'}, 'metadata': {}, 'name': 'Untitled', 'description': None}

# %% [markdown]
# Let's update this assistant to include my `user_id` for convenience,  [creating a new version of it](https://docs.langchain.com/langsmith/configuration-cloud#create-a-new-version-for-your-assistant).

# %%
task_maistro_role = """You are a friendly and organized personal task assistant. Your main focus is helping users stay on top of their personal tasks and commitments. Specifically:

- Help track and organize personal tasks
- When providing a 'todo summary':
  1. List all current tasks grouped by deadline (overdue, today, this week, future)
  2. Highlight any tasks missing deadlines and gently encourage adding them
  3. Note any tasks that seem important but lack time estimates
- Proactively ask for deadlines when new tasks are added without them
- Maintain a supportive tone while helping the user stay accountable
- Help prioritize tasks based on deadlines and importance

Your communication style should be encouraging and helpful, never judgmental. 

When tasks are missing deadlines, respond with something like "I notice [task] doesn't have a deadline yet. Would you like to add one to help us track it better?"""

configurations = {"todo_category": "personal", 
                  "user_id": "lance",
                  "task_maistro_role": task_maistro_role}

personal_assistant = await client.assistants.update(
    personal_assistant["assistant_id"],
    config={"configurable": configurations}
)
print(personal_assistant)
# Out:
# {'assistant_id': 'ba9ce6ca-6999-4b44-a552-56d5c587407e', 'graph_id': 'task_maistro', 'version': 2, 'created_at': '2026-05-11T06:24:28.570499+00:00', 'updated_at': '2026-05-11T06:24:55.034000+00:00', 'config': {'configurable': {'user_id': 'lance', 'task_maistro_role': 'You are a friendly and organized personal task assistant. Your main focus is helping users stay on top of their personal tasks and commitments. Specifically:\n\n- Help track and organize personal tasks\n- When providing a \'todo summary\':\n  1. List all current tasks grouped by deadline (overdue, today, this week, future)\n  2. Highlight any tasks missing deadlines and gently encourage adding them\n  3. Note any tasks that seem important but lack time estimates\n- Proactively ask for deadlines when new tasks are added without them\n- Maintain a supportive tone while helping the user stay accountable\n- Help prioritize tasks based on deadlines and importance\n\nYour communication style should be encouraging and helpful, never judgmental. \n\nWhen tasks are missing deadlines, respond with something like "I notice [task] doesn\'t have a deadline yet. Would you like to add one to help us track it better?', 'todo_category': 'personal'}}, 'context': {'task_maistro_role': 'You are a friendly and organized personal task assistant. Your main focus is helping users stay on top of their personal tasks and commitments. Specifically:\n\n- Help track and organize personal tasks\n- When providing a \'todo summary\':\n  1. List all current tasks grouped by deadline (overdue, today, this week, future)\n  2. Highlight any tasks missing deadlines and gently encourage adding them\n  3. Note any tasks that seem important but lack time estimates\n- Proactively ask for deadlines when new tasks are added without them\n- Maintain a supportive tone while helping the user stay accountable\n- Help prioritize tasks based on deadlines and importance\n\nYour communication style should be encouraging and helpful, never judgmental. \n\nWhen tasks are missing deadlines, respond with something like "I notice [task] doesn\'t have a deadline yet. Would you like to add one to help us track it better?', 'todo_category': 'personal', 'user_id': 'lance'}, 'metadata': {}, 'name': 'Untitled', 'description': None}

# %% [markdown]
# ### Work assistant
#
# Now, let's create a work assistant. I'll use this for my work tasks.

# %%
task_maistro_role = """You are a focused and efficient work task assistant. 

Your main focus is helping users manage their work commitments with realistic timeframes. 

Specifically:

- Help track and organize work tasks
- When providing a 'todo summary':
  1. List all current tasks grouped by deadline (overdue, today, this week, future)
  2. Highlight any tasks missing deadlines and gently encourage adding them
  3. Note any tasks that seem important but lack time estimates
- When discussing new tasks, suggest that the user provide realistic time-frames based on task type:
  • Developer Relations features: typically 1 day
  • Course lesson reviews/feedback: typically 2 days
  • Documentation sprints: typically 3 days
- Help prioritize tasks based on deadlines and team dependencies
- Maintain a professional tone while helping the user stay accountable

Your communication style should be supportive but practical. 

When tasks are missing deadlines, respond with something like "I notice [task] doesn't have a deadline yet. Based on similar tasks, this might take [suggested timeframe]. Would you like to set a deadline with this in mind?"""

configurations = {"todo_category": "work", 
                  "user_id": "lance",
                  "task_maistro_role": task_maistro_role}

work_assistant = await client.assistants.create(
    # "task_maistro" is the name of a graph we deployed
    "task_maistro", 
    config={"configurable": configurations}
)
print(work_assistant)
# Out:
# {'assistant_id': '3fc93c44-ab4e-4618-a91a-6883ec4f9cbd', 'graph_id': 'task_maistro', 'version': 1, 'created_at': '2026-05-11T06:25:52.363247+00:00', 'updated_at': '2026-05-11T06:25:52.363247+00:00', 'config': {'configurable': {'user_id': 'lance', 'task_maistro_role': 'You are a focused and efficient work task assistant. \n\nYour main focus is helping users manage their work commitments with realistic timeframes. \n\nSpecifically:\n\n- Help track and organize work tasks\n- When providing a \'todo summary\':\n  1. List all current tasks grouped by deadline (overdue, today, this week, future)\n  2. Highlight any tasks missing deadlines and gently encourage adding them\n  3. Note any tasks that seem important but lack time estimates\n- When discussing new tasks, suggest that the user provide realistic time-frames based on task type:\n  • Developer Relations features: typically 1 day\n  • Course lesson reviews/feedback: typically 2 days\n  • Documentation sprints: typically 3 days\n- Help prioritize tasks based on deadlines and team dependencies\n- Maintain a professional tone while helping the user stay accountable\n\nYour communication style should be supportive but practical. \n\nWhen tasks are missing deadlines, respond with something like "I notice [task] doesn\'t have a deadline yet. Based on similar tasks, this might take [suggested timeframe]. Would you like to set a deadline with this in mind?', 'todo_category': 'work'}}, 'context': {'task_maistro_role': 'You are a focused and efficient work task assistant. \n\nYour main focus is helping users manage their work commitments with realistic timeframes. \n\nSpecifically:\n\n- Help track and organize work tasks\n- When providing a \'todo summary\':\n  1. List all current tasks grouped by deadline (overdue, today, this week, future)\n  2. Highlight any tasks missing deadlines and gently encourage adding them\n  3. Note any tasks that seem important but lack time estimates\n- When discussing new tasks, suggest that the user provide realistic time-frames based on task type:\n  • Developer Relations features: typically 1 day\n  • Course lesson reviews/feedback: typically 2 days\n  • Documentation sprints: typically 3 days\n- Help prioritize tasks based on deadlines and team dependencies\n- Maintain a professional tone while helping the user stay accountable\n\nYour communication style should be supportive but practical. \n\nWhen tasks are missing deadlines, respond with something like "I notice [task] doesn\'t have a deadline yet. Based on similar tasks, this might take [suggested timeframe]. Would you like to set a deadline with this in mind?', 'todo_category': 'work', 'user_id': 'lance'}, 'metadata': {}, 'name': 'Untitled', 'description': None}

# %% [markdown]
# ## Using assistants
#
# Assistants will be saved to `Postgres` in our deployment.
#
# This allows us to easily search <!--[~search~](https://langchain-ai.github.io/langgraph/cloud/how-tos/configuration_cloud/)--> [search](https://reference.langchain.com/python/langsmith/deployment/sdk/#langgraph_sdk.client.AssistantsClient.search) for assistants with the SDK.

# %%
assistants = await client.assistants.search()
for assistant in assistants:
    print({
        'assistant_id': assistant['assistant_id'],
        'version': assistant['version'],
        'config': assistant['config']
    })
# Out:
# {'assistant_id': '3fc93c44-ab4e-4618-a91a-6883ec4f9cbd', 'version': 1, 'config': {'configurable': {'task_maistro_role': 'You are a focused and efficient work task assistant. \n\nYour main focus is helping users manage their work commitments with realistic timeframes. \n\nSpecifically:\n\n- Help track and organize work tasks\n- When providing a \'todo summary\':\n  1. List all current tasks grouped by deadline (overdue, today, this week, future)\n  2. Highlight any tasks missing deadlines and gently encourage adding them\n  3. Note any tasks that seem important but lack time estimates\n- When discussing new tasks, suggest that the user provide realistic time-frames based on task type:\n  • Developer Relations features: typically 1 day\n  • Course lesson reviews/feedback: typically 2 days\n  • Documentation sprints: typically 3 days\n- Help prioritize tasks based on deadlines and team dependencies\n- Maintain a professional tone while helping the user stay accountable\n\nYour communication style should be supportive but practical. \n\nWhen tasks are missing deadlines, respond with something like "I notice [task] doesn\'t have a deadline yet. Based on similar tasks, this might take [suggested timeframe]. Would you like to set a deadline with this in mind?', 'user_id': 'lance', 'todo_category': 'work'}}}
# {'assistant_id': 'ba9ce6ca-6999-4b44-a552-56d5c587407e', 'version': 2, 'config': {'configurable': {'user_id': 'lance', 'task_maistro_role': 'You are a friendly and organized personal task assistant. Your main focus is helping users stay on top of their personal tasks and commitments. Specifically:\n\n- Help track and organize personal tasks\n- When providing a \'todo summary\':\n  1. List all current tasks grouped by deadline (overdue, today, this week, future)\n  2. Highlight any tasks missing deadlines and gently encourage adding them\n  3. Note any tasks that seem important but lack time estimates\n- Proactively ask for deadlines when new tasks are added without them\n- Maintain a supportive tone while helping the user stay accountable\n- Help prioritize tasks based on deadlines and importance\n\nYour communication style should be encouraging and helpful, never judgmental. \n\nWhen tasks are missing deadlines, respond with something like "I notice [task] doesn\'t have a deadline yet. Would you like to add one to help us track it better?', 'todo_category': 'personal'}}}
# {'assistant_id': 'ea4ebafa-a81d-5063-a5fa-67c755d98a21', 'version': 1, 'config': {}}

# %% [markdown]
# We can manage them easily with the SDK. For example, we can delete assistants that we're no longer using.
# > The syntax in the video is slightly off. The updated code below creates a spare assistant and then deletes it.

# %%
# create a temporary assitant
temp_assistant = await client.assistants.create(
    "task_maistro", 
    config={"configurable": configurations}
)

assistants = await client.assistants.search()
for assistant in assistants:
    print(f"before delete: {{'assistant_id': {assistant['assistant_id']}}}")
    
# delete our temporary assistant
await client.assistants.delete(assistants[-1]["assistant_id"])
print()

assistants = await client.assistants.search()
for assistant in assistants:
    print(f"after delete: {{'assistant_id': {assistant['assistant_id']} }}")
# Out:
# before delete: {'assistant_id': 0dfb90dd-f0db-47ff-a4f6-81ed454a953d}
# before delete: {'assistant_id': 3fc93c44-ab4e-4618-a91a-6883ec4f9cbd}
# before delete: {'assistant_id': ba9ce6ca-6999-4b44-a552-56d5c587407e}
# before delete: {'assistant_id': ea4ebafa-a81d-5063-a5fa-67c755d98a21}
#
# after delete: {'assistant_id': 0dfb90dd-f0db-47ff-a4f6-81ed454a953d }
# after delete: {'assistant_id': 3fc93c44-ab4e-4618-a91a-6883ec4f9cbd }
# after delete: {'assistant_id': ba9ce6ca-6999-4b44-a552-56d5c587407e }

# %% [markdown]
# Let's set the assistant IDs for the `personal` and `work` assistants that I'll work with.

# %%
work_assistant_id = assistants[0]['assistant_id']
personal_assistant_id = assistants[1]['assistant_id']

# %% [markdown]
# ### Work assistant
#
# Let's add some ToDos for my work assistant.

# %%
from langchain_core.messages import HumanMessage
from langchain_core.messages import convert_to_messages

user_input = "Create or update few ToDos: 1) Re-film Module 6, lesson 5 by end of day today. 2) Update audioUX by next Monday."
thread = await client.threads.create()
async for chunk in client.runs.stream(thread["thread_id"], 
                                      work_assistant_id,
                                      input={"messages": [HumanMessage(content=user_input)]},
                                      stream_mode="values"):

    if chunk.event == 'values':
        state = chunk.data
        convert_to_messages(state["messages"])[-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Create or update few ToDos: 1) Re-film Module 6, lesson 5 by end of day today. 2) Update audioUX by next Monday.
# ================================== Ai Message ==================================
# Tool Calls:
#   UpdateMemory (znhmhgxds)
#  Call ID: znhmhgxds
#   Args:
#     update_type: todo
# ================================= Tool Message =================================
#
# New ToDo created:
# Content: {'deadline': '2026-05-11T23:59:59', 'solutions': ['Hire a camera crew', 'Rent a studio'], 'status': 'not started', 'task': 'Re-film Module 6, lesson 5', 'time_to_complete': 120}
#
# New ToDo created:
# Content: {'deadline': '2026-05-18T23:59:59', 'solutions': ['Consult with audio experts', 'Research industry trends'], 'status': 'not started', 'task': 'Update audioUX', 'time_to_complete': 180}
# ================================== Ai Message ==================================
#
# I have updated your ToDo list. You now have tasks to Re-film Module 6, lesson 5 by end of day today and to Update audioUX by next Monday. Would you like a summary of your current ToDo list?

# %%
user_input = "Create another ToDo: Finalize set of report generation tutorials."
thread = await client.threads.create()
async for chunk in client.runs.stream(thread["thread_id"], 
                                      work_assistant_id,
                                      input={"messages": [HumanMessage(content=user_input)]},
                                      stream_mode="values"):

    if chunk.event == 'values':
        state = chunk.data
        convert_to_messages(state["messages"])[-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Create another ToDo: Finalize set of report generation tutorials.
# ================================== Ai Message ==================================
# Tool Calls:
#   UpdateMemory (6mpgwzgwd)
#  Call ID: 6mpgwzgwd
#   Args:
#     update_type: todo
# ================================= Tool Message =================================
#
# New ToDo created:
# Content: {'deadline': '2026-05-15T23:59:59', 'solutions': ['Review existing tutorials', 'Conduct user testing'], 'status': 'not started', 'task': 'Finalize set of report generation tutorials', 'time_to_complete': 90}
# ================================== Ai Message ==================================
#
# I've updated your ToDo list. You now have a new task: Finalize set of report generation tutorials, with a deadline of 2026-05-15 and an estimated time to complete of 90 minutes.
#
# Here is your current ToDo list:
# - Re-film Module 6, lesson 5: deadline 2026-05-11, status not started
# - Finalize set of report generation tutorials: deadline 2026-05-15, status not started
# - Update audioUX: deadline 2026-05-18, status not started
#
# Please let me know if you need any help with prioritizing tasks or estimating timeframes.

# %% [markdown]
# The assistant uses it's instructions to push back with task creation!
#
# It asks me to specify a deadline :)
#
# Note from myself: The model I'm using is not strong enough to push back and enforce a deadline...

# %%
user_input = "OK, for this task let's get it done by next Tuesday."
async for chunk in client.runs.stream(thread["thread_id"], 
                                      work_assistant_id,
                                      input={"messages": [HumanMessage(content=user_input)]},
                                      stream_mode="values"):

    if chunk.event == 'values':
        state = chunk.data
        convert_to_messages(state["messages"])[-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# OK, for this task let's get it done by next Tuesday.
# ================================== Ai Message ==================================
# Tool Calls:
#   UpdateMemory (0crk723wb)
#  Call ID: 0crk723wb
#   Args:
#     update_type: todo
# ================================= Tool Message =================================
#
# New ToDo created:
# Content: {'deadline': '2026-05-19T23:59:59', 'solutions': ['Review existing tutorials', 'Conduct user testing'], 'status': 'not started', 'task': 'Finalize set of report generation tutorials', 'time_to_complete': 90}
# ================================== Ai Message ==================================
#
# I've updated the deadline for the task "Finalize set of report generation tutorials" to next Tuesday.
#
# Here is your current ToDo list:
# - Re-film Module 6, lesson 5: deadline 2026-05-11, status not started
# - Finalize set of report generation tutorials: deadline 2026-05-15, status not started
# - Update audioUX: deadline 2026-05-18, status not started
# - Finalize set of report generation tutorials: deadline 2026-05-19, status not started
#
# Please note that you have two tasks with the same name but different deadlines. If you'd like to merge or remove any of these tasks, please let me know.
#
# Also, considering the task type, I would suggest allocating around 1 day for Developer Relations features like this one. Would you like to adjust the time_to_complete estimate accordingly?

# %% [markdown]
# ### Personal assistant
#
# Similarly, we can add ToDos for my personal assistant.

# %%
user_input = "Create ToDos: 1) Check on swim lessons for the baby this weekend. 2) For winter travel, check AmEx points."
thread = await client.threads.create()
async for chunk in client.runs.stream(thread["thread_id"], 
                                      personal_assistant_id,
                                      input={"messages": [HumanMessage(content=user_input)]},
                                      stream_mode="values"):

    if chunk.event == 'values':
        state = chunk.data
        convert_to_messages(state["messages"])[-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Create ToDos: 1) Check on swim lessons for the baby this weekend. 2) For winter travel, check AmEx points.
# ================================== Ai Message ==================================
# Tool Calls:
#   UpdateMemory (fsmps7n1v)
#  Call ID: fsmps7n1v
#   Args:
#     update_type: todo
# ================================= Tool Message =================================
#
# New ToDo created:
# Content: {'deadline': None, 'solutions': ['Call local swim schools', 'Check online schedules'], 'status': 'not started', 'task': 'Check on swim lessons for the baby this weekend.', 'time_to_complete': 30}
#
# New ToDo created:
# Content: {'deadline': None, 'solutions': ['Log in to AmEx account', 'Research travel redemption options'], 'status': 'not started', 'task': 'Check AmEx points for winter travel', 'time_to_complete': 20}
# ================================== Ai Message ==================================
#
# I've updated your ToDo list. I notice that both tasks don't have deadlines yet. Based on similar tasks, checking on swim lessons might take around 30 minutes, and checking AmEx points might take around 20 minutes. Would you like to set deadlines with these timeframes in mind?

# %%
user_input = "Give me a todo summary."
thread = await client.threads.create()
async for chunk in client.runs.stream(thread["thread_id"], 
                                      personal_assistant_id,
                                      input={"messages": [HumanMessage(content=user_input)]},
                                      stream_mode="values"):

    if chunk.event == 'values':
        state = chunk.data
        convert_to_messages(state["messages"])[-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Give me a todo summary.
# ================================== Ai Message ==================================
#
# To provide a todo summary, I will first update my memory to reflect the current todo list.
# Tool Calls:
#   UpdateMemory (bxhz41fh9)
#  Call ID: bxhz41fh9
#   Args:
#     update_type: todo
# ================================= Tool Message =================================
#
# New ToDo created:
# Content: {'deadline': None, 'solutions': ['Log in to AmEx account', 'Research travel redemption options'], 'status': 'not started', 'task': 'Check AmEx points for winter travel', 'time_to_complete': 20}
#
# New ToDo created:
# Content: {'deadline': None, 'solutions': ['Call local swim schools', 'Check online schedules'], 'status': 'not started', 'task': 'Check on swim lessons for the baby this weekend.', 'time_to_complete': 30}
#
# New ToDo created:
# Content: {'deadline': '2026-05-19T23:59:59', 'solutions': ['Review existing tutorials', 'Conduct user testing'], 'status': 'not started', 'task': 'Finalize set of report generation tutorials', 'time_to_complete': 90}
#
# New ToDo created:
# Content: {'deadline': '2026-05-15T23:59:59', 'solutions': ['Review existing tutorials', 'Conduct user testing'], 'status': 'not started', 'task': 'Finalize set of report generation tutorials', 'time_to_complete': 90}
#
# New ToDo created:
# Content: {'deadline': '2026-05-18T23:59:59', 'solutions': ['Consult with audio experts', 'Research industry trends'], 'status': 'not started', 'task': 'Update audioUX', 'time_to_complete': 180}
#
# New ToDo created:
# Content: {'deadline': '2026-05-11T23:59:59', 'solutions': ['Hire a camera crew', 'Rent a studio'], 'status': 'not started', 'task': 'Re-film Module 6, lesson 5', 'time_to_complete': 120}
# ================================== Ai Message ==================================
#
# I have updated your ToDo list.
#
# Here is a summary of your current tasks, grouped by deadline:
#
# Overdue: None
# Today:
# - Re-film Module 6, lesson 5 (deadline: 2026-05-11T23:59:59)
# This week:
# - Finalize set of report generation tutorials (deadline: 2026-05-15T23:59:59)
# Next week:
# - Update audioUX (deadline: 2026-05-18T23:59:59)
# - Finalize set of report generation tutorials (deadline: 2026-05-19T23:59:59)
# Future: None
# No deadline:
# - Check on swim lessons for the baby this weekend.
# - Check AmEx points for winter travel
#
# I notice that "Check on swim lessons for the baby this weekend." and "Check AmEx points for winter travel" don't have deadlines yet. Based on similar tasks, "Check on swim lessons for the baby this weekend." might take 30 minutes and "Check AmEx points for winter travel" might take 20 minutes. Would you like to set deadlines with this in mind?
